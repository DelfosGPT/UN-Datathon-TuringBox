# %%
places = {
    "Medellín": {
        "Comunidades": [
            # "Comuna Popular", "Comuna Santa Cruz", "Comuna Manrique", 
            #             "Comuna Aranjuez", "Comuna Castilla", "Comuna Doce de Octubre", 
                        "Comuna Robledo", 
                        # "Comuna Villa Hermosa", 
                        "Comuna Buenos Aires", 
                        # "Comuna La Candelaria", "Comuna Laureles-Estadio", 
                        # "Comuna La América", "Comuna San Javier", 
                        # "Comuna El Poblado", 
                        # "Comuna Guayabal", "Comuna Belén"
                        ],
        "Corregimientos": ["San Sebastián de Palmitas", "San Cristóbal", "Altavista", "San Antonio de Prado", "Santa Elena"]
    },
    "Bello": {
        "Barrios": ["Niquía", "París", "Zamora", "Santa Ana", "Fontidueño", "El Trapiche"]
    },
    "Envigado": {
        "Barrios": ["El Dorado", "San Marcos", "El Trianón", "La Magnolia", "Las Antillas", "El Salado"],
        "Zonas rurales": ["El Vallano", "Alto de Las Palmas"]
    },
    "Itagüí": {
        "Barrios": ["Santa María", "Ditaires", "El Rosario", "San Gabriel", "Villa Paula"],
    },
    "Sabaneta": {
        "Barrios": ["La Doctora", "Aliadas", "San José", "Las Lomitas"]
    },
    "La Estrella": {
        "Barrios": ["San Agustín", "Las Brisas", "Suramérica", "La Ferrería"]
    },
    "Caldas": {
        "Barrios": ["La Inmaculada", "La Asunción", "La Valeria", "La Pradera"]
    },
    "Copacabana": {
        "Barrios": ["El Recreo", "El Pedregal", "La Pedrera"]
    },
    "Girardota": {
        "Zonas Urbanas": ["Zona Centro", "San Diego", "El Llano"]
    },
    "Barbosa": {
        "Zonas Urbanas": ["Centro", "Machado", "El Hatillo"]
    }
}

cords = {
    "Comuna Popular": "https://www.google.com/maps/@6.3042295,-75.5513746,16z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D",
    "Comuna Santa Cruz": "https://www.google.com/maps/@6.2930215,-75.5588579,17z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D",
    "Comuna Manrique": "https://www.google.com/maps/@6.2689654,-75.5473832,16.34z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D", 
    "Comuna Aranjuez": "https://www.google.com/maps/@6.2830811,-75.5777798,15z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D",
    "Comuna Castilla": "https://www.google.com/maps/@6.2917204,-75.5779338,16z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D", 
    "Comuna Doce de Octubre": "https://www.google.com/maps/@6.3020681,-75.5816456,15.81z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D", 
    "Comuna Robledo": "https://www.google.com/maps/@39.2178016,-4.284476,15.52z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D",
    "Comuna Villa Hermosa": "https://www.google.com/maps/@6.24759,-75.5554641,15.44z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D", 
    "Comuna Buenos Aires": "https://www.google.com/maps/@6.2383113,-75.5595339,16z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D", 
    "Comuna La Candelaria": "https://www.google.com/maps/@6.2463071,-75.5791721,15.63z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D",
    "Comuna Laureles-Estadio": "https://www.google.com/maps/@6.2524967,-75.5997339,14.8z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D", 
    "Comuna La América": "https://www.google.com/maps/@6.2554805,-75.6071289,15.69z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D",
    "Comuna San Javier": "https://www.google.com/maps/@6.2552154,-75.6266392,15.74z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D", 
    "Comuna El Poblado": "https://www.google.com/maps/@6.209337,-75.5702626,17z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D", 
    "Comuna Guayabal": "https://www.google.com/maps/@6.2098079,-75.5885941,14.39z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D",
    "Comuna Belén": "https://www.google.com/maps/@6.2262257,-75.6077478,14.53z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D"
}

common = ["Museos", "Parques temático","Parques de atracciones", "Parques acuaticos", "Jardines", "Cines"]

sites = ["Restaurantes", "Hoteles", "Parques", "Comida rápida", 
        "Bares", "Discotecas", "Cines", "Teatros", "Jardines",
        "Museos", "Parques temático", "Centros comerciales", 
        "Parques de atracciones", "Parques acuaticos"]

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import re
import time
import datetime

# %%
url = "https://www.google.com/maps/@6.2297192,-75.5601012,13.19z?hl=es&entry=ttu&g_ep=EgoyMDI0MTEwNi4wIKXMDSoASAFQAw%3D%3D"

# %%
driver = webdriver.Chrome()

# %%
data = {
    "name": [],
    "desc": [],
    "score": [],
    "c_score": [],
    "price": [],
    "category": [],
    "accessibility": [],
    "schedule": [],
    "web": [],
    "search_parameters": [],
    "phone": [],
    "address": [],
    "lat": [], 
    "lon": []
}

for place in places["Medellín"]["Comunidades"]:
    for site in sites:
        try:
            driver.get(cords[place])
            time.sleep(2)
            search_input = driver.find_element(By.XPATH, '//*[@id="searchboxinput"]')
            search_button = driver.find_element(By.XPATH, '//*[@id="searchbox-searchbutton"]/span')
            
            search_input.clear()
            
            search_input.send_keys(f"{site} en {place}")
            search_button.click()

            driver.implicitly_wait(4)

            sites_lists = driver.find_elements(By.CLASS_NAME, 'hfpxzc')
            if site not in common:
                driver.execute_script("arguments[0].scrollIntoView()", sites_lists[-1])
                time.sleep(0.5)
                sites_lists = driver.find_elements(By.CLASS_NAME, 'hfpxzc')

            publicity =  len(driver.find_elements(By.XPATH, "//*[@class='geckTe FcJlLe']"))
            if publicity != 0:
                sites_lists = sites_lists[publicity:]

            for i in sites_lists:
                driver.execute_script("arguments[0].scrollIntoView()", i)
                time.sleep(0.5)
                url = i.get_attribute("href")
                driver.execute_script(f"window.open('{url}', '_blank');")
                driver.switch_to.window(driver.window_handles[1])
                time.sleep(2)
                try:
                    name = driver.find_elements(By.XPATH, "//*[@class='DUwDvf lfPIob']")
                    if len(name) > 0:
                        
                        data["name"].append(name[0].text)
                    else:
                        data["name"].append(pd.NA)

                    scores = driver.find_elements(By.XPATH, "//*[@class='F7nice ']")
                    if len(scores) > 0:
                        score = pd.NA
                        c_score = pd.NA
                        try:
                            score, c_score = tuple(map(lambda x: float(x), scores[0].text.replace("(", "").replace(")", "").replace(".", "").replace(",", ".").split("\n")))
                        except:
                            pass
                        
                        data["score"].append(score)
                        data["c_score"].append(c_score)
                    else:
                        data["score"].append(pd.NA)
                        data["c_score"].append(pd.NA)

                    prices = driver.find_elements(By.XPATH, "//*[@class='mgr77e']")
                    if len(prices) > 0:
                        
                        data["price"].append(prices[0].text.replace("·", ""))
                    else:
                        data["price"].append(pd.NA)
                        
                    
                    category = driver.find_elements(By.XPATH, "//*[@class='DkEaL ']")
                    if len(category) > 0:
                        
                        data["category"].append(category[0].text)
                    else:
                        data["category"].append(pd.NA)
                        
                    accessibility = driver.find_elements(By.XPATH, "//*[@class='wmQCje google-symbols']")
                    if len(accessibility) > 0:
                        
                        data["accessibility"].append(accessibility[0].get_attribute("aria-label"))
                    else:
                        data["accessibility"].append(pd.NA)

                    webs = driver.find_elements(By.XPATH, "//*[@class='CsEnBe']")
                    
                    driver.execute_script("arguments[0].scrollIntoView()", webs[0])
                    
                    
                    address = driver.find_elements(By.XPATH, "//*[@class='Io6YTe fontBodyMedium kR99db fdkmkc ']")
                    if len(address) > 0:
                        
                        data["address"].append(address[0].text)
                    else:
                        data["address"].append(pd.NA)
                        
                    if len(webs) > 0:
                        for web in webs:
                            if web.get_attribute("aria-label") is not None:
                                if web.get_attribute("aria-label").startswith("Teléfono: "):
                                    
                                    data["phone"].append(web.get_attribute("aria-label").replace("Teléfono: ", ""))
                                elif web.get_attribute("aria-label").startswith("Sitio web: "):
                                    if web.get_attribute("href") is not None and web.get_attribute("href") != "":
                                        
                                        data["web"].append(web.get_attribute("href"))
                                    else:
                                        data["web"].append(pd.NA)
                    else:
                        data["phone"].append(pd.NA)
                        data["web"].append(pd.NA)
                        
                    if len(data["web"]) != len(data["name"]):
                        data["web"].append(pd.NA)
                    if len(data["phone"]) != len(data["name"]):
                        data["phone"].append(pd.NA)
                    
                    
                    data["search_parameters"].append(f"{place} {site}")
                    schedules = driver.find_elements(By.XPATH, "//*[@class='g2BVhd eoFzo ']")
                    if len(schedules) > 0:
                        driver.execute_script("arguments[0].scrollIntoView()", schedules[0])
                        time.sleep(1)
                        
                        inicio = None
                        fin = None
                        try:
                            for horario in driver.find_elements(By.XPATH, "//*[@class='dpoVLd finExf']"):
                                # Extraemos la ocupación y la hora del string
                                ocupacion = int(re.findall("ocupación: (\d*)", horario.get_attribute("aria-label"))[0])
                                hora = horario.get_attribute("aria-label").split("hora:")[1].strip().replace(' ', ' ')

                                if ocupacion > 0 and inicio is None:
                                    # Establecer el inicio del rango cuando la ocupación no es 0
                                    inicio = hora
                                if ocupacion == 0 and inicio is not None:
                                    # Establecer el final del rango cuando la ocupación vuelva a ser 0
                                    fin = hora
                                    break

                            data["schedule"].append(str(str(inicio) + "," + str(fin)).replace("p.\xa0m.)", "pm").replace("a.\xa0m.)", ""))
                        except:
                            data["schedule"].append(pd.NA)
                    else:
                        data["schedule"].append(pd.NA)
                    
                    driver.execute_script("arguments[0].scrollIntoView()", name[0])
                    time.sleep(1)
                    
                    info_button = driver.find_elements(By.XPATH, "//*[@class='hh2c6 ']")
                    try:
                        info_button[-1].click()
                        info = driver.find_elements(By.XPATH, "//*[@class='m6QErb DxyBCb kA9KIf dS8AEf XiKgde ']")

                        if len(info) > 0:
                            data["desc"].append(str(info_button[-1].get_attribute("aria-label").split()[0] + ",".join([i.text for i in info])))
                        else:
                            data["desc"].append(pd.NA)
                    except:
                        data["desc"].append(pd.NA)
                    

                    time.sleep(3)
                    lat, lon = [float(x) for x in re.findall(r"@(.*),", driver.current_url)[0].split(",")]
                    data["lat"].append(lat)
                    data["lon"].append(lon)
                except:
                    max = 0
                    for i, list in data.items():
                        if max < len(list):
                            max = len(list)
                            
                    for i , list in data.items():
                        if len(list) > max:
                            list.pop()

                    data["name"].append(pd.NA)
                    data["score"].append(pd.NA)
                    data["c_score"].append(pd.NA)
                    data["price"].append(pd.NA)
                    data["category"].append(pd.NA)
                    data["accessibility"].append(pd.NA)
                    data["address"].append(pd.NA)
                    data["phone"].append(pd.NA)
                    data["web"].append(pd.NA)
                    data["schedule"].append(pd.NA)
                    data["desc"].append(pd.NA)
                    data["lat"].append(pd.NA)
                    data["lon"].append(pd.NA)
                    data["search_parameters"].append(pd.NA)
                    
                driver.close()

                driver.switch_to.window(driver.window_handles[0])
        except:
            pass

# %%
for i, list in data.items():
    print(i, len(list))
# Out:
# name 88
# desc 87
# score 88
# c_score 88
# price 88
# category 88
# accessibility 88
# schedule 87
# web 87
# search_parameters 87
# phone 87
# address 87
# lat 87
# lon 87

# %%
# max = 0
# pop = False
# for i, list in data.items():
#     if max < len(list):
#         max = len(list)
        
#         if pop == False and max != 0:
#             pop = True
#             break
        
# for i , list in data.items():
#     if len(list) == max and pop == True:
#         print(i)
#         list.pop()

# %%
df = pd.DataFrame(data)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.DataFrame(data)
#       2 df.head()
#
# File c:\Users\JUAN\anaconda3\envs\UN-Datathon\lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File c:\Users\JUAN\anaconda3\envs\UN-Datathon\lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
# ...

# %%
df.to_csv("intento9.csv")

# %%
# for comuna in places["Medellín"]["Comunidades"]:
#     for site in sites:
#         search.send_keys(f"{comuna} {site}")
